# %% [markdown]
# # DAP Mini Project
#
# ## Suicide Rates in India 2001-2012
#
# ## Presented by -
# ### A063 Renu Rao
# ### A070 Garima Singh
# ### A075 Dakshita Thakkar

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing the dataset
df = pd.read_csv('Suicides in India 2001-2012.csv')
df.head(10)
# Out:
#            State  Year Type_code                                     Type  \
# 0  A & N Islands  2001    Causes                       Illness (Aids/STD)
# 1  A & N Islands  2001    Causes  Bankruptcy or Sudden change in Economic
# 2  A & N Islands  2001    Causes  Cancellation/Non-Settlement of Marriage
# 3  A & N Islands  2001    Causes        Physical Abuse (Rape/Incest Etc.)
# 4  A & N Islands  2001    Causes                            Dowry Dispute
# 5  A & N Islands  2001    Causes                          Family Problems
# 6  A & N Islands  2001    Causes      Ideological Causes/Hero Worshipping
# 7  A & N Islands  2001    Causes                  Other Prolonged Illness
# 8  A & N Islands  2001    Causes                         Property Dispute
# 9  A & N Islands  2001    Causes                Fall in Social Reputation
#
#    Gender Age_group  Total
# 0  Female      0-14      0
# 1  Female      0-14      0
# 2  Female      0-14      0
# 3  Female      0-14      0
# ...

# %%
# No of rows and columns
df.shape
# Out:
# (237519, 7)

# %% [markdown]
# Thus, the dataset contains 237519 rows and 7 columns

# %%
# Datatypes of the columns
df.dtypes
# Out:
# State        object
# Year          int64
# Type_code    object
# Type         object
# Gender       object
# Age_group    object
# Total         int64
# dtype: object

# %%
# Names of the columns
df.columns
# Out:
# Index(['State', 'Year', 'Type_code', 'Type', 'Gender', 'Age_group', 'Total'], dtype='object')

# %%
# Info of the columns at a glance
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237519 entries, 0 to 237518
# Data columns (total 7 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   State      237519 non-null  object
#  1   Year       237519 non-null  int64
#  2   Type_code  237519 non-null  object
#  3   Type       237519 non-null  object
#  4   Gender     237519 non-null  object
#  5   Age_group  237519 non-null  object
#  6   Total      237519 non-null  int64
# dtypes: int64(2), object(5)
# memory usage: 12.7+ MB

# %%
# Various statistics about the numerical columns in the dataset
df.describe()
# Out:
#                 Year          Total
# count  237519.000000  237519.000000
# mean     2006.500448      55.034477
# std         3.452240     792.749038
# min      2001.000000       0.000000
# 25%      2004.000000       0.000000
# 50%      2007.000000       0.000000
# 75%      2010.000000       6.000000
# max      2012.000000   63343.000000

# %% [markdown]
# ## Data Cleaning

# %%
# checking no of rows and columns in the dataset before cleaning
df.shape
# Out:
# (237519, 7)

# %%
# Checking for null values
df.isnull()
# Out:
#         State   Year  Type_code   Type  Gender  Age_group  Total
# 0       False  False      False  False   False      False  False
# 1       False  False      False  False   False      False  False
# 2       False  False      False  False   False      False  False
# 3       False  False      False  False   False      False  False
# 4       False  False      False  False   False      False  False
# ...       ...    ...        ...    ...     ...        ...    ...
# 237514  False  False      False  False   False      False  False
# 237515  False  False      False  False   False      False  False
# 237516  False  False      False  False   False      False  False
# 237517  False  False      False  False   False      False  False
# 237518  False  False      False  False   False      False  False
#
# [237519 rows x 7 columns]

# %%
# total no of null values per column
df.isnull().sum()
# Out:
# State        0
# Year         0
# Type_code    0
# Type         0
# Gender       0
# Age_group    0
# Total        0
# dtype: int64

# %%
# Total no of null values in the entire dataset
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Thus, there are no null values in the dataset

# %%
# Checking for duplicate values
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 237514    False
# 237515    False
# 237516    False
# 237517    False
# 237518    False
# Length: 237519, dtype: bool

# %%
# Dropping any duplicate values
df.drop_duplicates()
# Out:
#                 State  Year      Type_code  \
# 0       A & N Islands  2001         Causes
# 1       A & N Islands  2001         Causes
# 2       A & N Islands  2001         Causes
# 3       A & N Islands  2001         Causes
# 4       A & N Islands  2001         Causes
# ...               ...   ...            ...
# 237514    West Bengal  2012  Social_Status
# 237515    West Bengal  2012  Social_Status
# 237516    West Bengal  2012  Social_Status
# 237517    West Bengal  2012  Social_Status
# 237518    West Bengal  2012  Social_Status
#
#                                            Type  Gender Age_group  Total
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...

# %%
# Checking no of rows and columns in the dataset after cleaning
df.shape
# Out:
# (237519, 7)

# %% [markdown]
# The numebr of rows and columns before and after cleaning is the same. Thus, the data is cleaned properly.

# %% [markdown]
# ## Data visualization

# %%
sns.lineplot(data=df, x='Year', y='Total', color='orange', marker='o')
plt.title('Total number of cases per year')
plt.xlabel('Year')
plt.ylabel('Number of cases')
# Out:
# Text(0, 0.5, 'Number of cases')

# %%
# Checking unique values in State column
df['State'].unique()
# Out:
# array(['A & N Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam',
#        'Bihar', 'Chandigarh', 'Chhattisgarh', 'D & N Haveli',
#        'Daman & Diu', 'Delhi (Ut)', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Total (All India)', 'Total (States)', 'Total (Uts)', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal'], dtype=object)

# %%
# Removed the Total (All India), Total (States), Total (Uts) columns from State column
df1 = df[df['State'] != 'Total (All India)']
df1 = df1[df1['State'] != 'Total (States)']
df1 = df1[df1['State'] != 'Total (Uts)']
df1['State'].unique()
# Out:
# array(['A & N Islands', 'Andhra Pradesh', 'Arunachal Pradesh', 'Assam',
#        'Bihar', 'Chandigarh', 'Chhattisgarh', 'D & N Haveli',
#        'Daman & Diu', 'Delhi (Ut)', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland', 'Odisha',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'West Bengal'],
#       dtype=object)

# %%
plt.figure(figsize=(6, 6))
sns.barplot(data=df1, x='Total', y='State')
plt.title('State & UT wise total no of suicide cases')
# Out:
# Text(0.5, 1.0, 'State & UT wise total no of suicide cases')

# %%
df2 = df[df['State'] == 'Total (States)']
sns.boxplot(data=df2, x='Year', y='Total')
plt.title('Total no of suicide cases per year (for states only)')
# Out:
# Text(0.5, 1.0, 'Total no of suicide cases per year (for states only)')

# %%
df3 = df[df['State'] == 'Total (Uts)']
sns.boxplot(data=df3, x='Year', y='Total')
plt.title('Total no of suicide cases per year (for UT only)')
# Out:
# Text(0.5, 1.0, 'Total no of suicide cases per year (for UT only)')

# %%
# Checking unique values in Age_group column
df['Age_group'].unique()
# Out:
# array(['0-14', '15-29', '30-44', '45-59', '60+', '0-100+'], dtype=object)

# %%
df4 = df[df['Age_group'] != '0-100+']
# df4
sns.barplot(data=df4, x='Total', y='Age_group', hue='Age_group', palette='flare', linewidth=1, edgecolor='black')
plt.title('No of suicide cases as per age group')
# Out:
# Text(0.5, 1.0, 'No of suicide cases as per age group')

# %%
# Creating a dictionary mapping states to regions
region_mapping = {
    'A & N Islands': 'Southern',
    'Andhra Pradesh': 'Southern',
    'Arunachal Pradesh': 'North Eastern',
    'Assam': 'North Eastern',
    'Bihar': 'Eastern',
    'Chandigarh': 'Northern',
    'Chhattisgarh': 'Central',
    'D & N Haveli': 'Western',
    'Daman & Diu': 'Western',
    'Delhi (Ut)': 'Northern',
    'Goa': 'Western',
    'Gujarat': 'Western', 
    'Haryana': 'Northern',
    'Himachal Pradesh': 'Northern',
    'Jammu & Kashmir': 'Northern',
    'Jharkhand': 'Eastern',
    'Karnataka': 'Southern',
    'Kerala': 'Southern',
    'Lakshadweep': 'Southern',
    'Madhya Pradesh': 'Central',
    'Maharashtra': 'Western',
    'Manipur': 'North Eastern',
    'Meghalaya': 'North Eastern',
    'Mizoram': 'North Eastern',
    'Nagaland': 'North Eastern',
    'Odisha': 'Eastern',
    'Puducherry': 'Southern',
    'Punjab': 'Northern',
    'Rajasthan': 'Western',
    'Sikkim': 'North Eastern',
    'Tamil Nadu': 'Southern',
    'Total (All India)': '',
    'Total (States)': '',
    'Total (Uts)': '',
    'Tripura': 'North Eastern',
    'Uttar Pradesh': 'Northern',
    'Uttarakhand': 'Northern',
    'West Bengal': 'Eastern'
}

# %%
# Creating a function that maps states to region
def map_state_to_region(state):
    return region_mapping.get(state, 'Unknown')

df['Region'] = df['State'].apply(map_state_to_region)

# %%
df
# Out:
#                 State  Year      Type_code  \
# 0       A & N Islands  2001         Causes
# 1       A & N Islands  2001         Causes
# 2       A & N Islands  2001         Causes
# 3       A & N Islands  2001         Causes
# 4       A & N Islands  2001         Causes
# ...               ...   ...            ...
# 237514    West Bengal  2012  Social_Status
# 237515    West Bengal  2012  Social_Status
# 237516    West Bengal  2012  Social_Status
# 237517    West Bengal  2012  Social_Status
# 237518    West Bengal  2012  Social_Status
#
#                                            Type  Gender Age_group  Total  \
# 0                            Illness (Aids/STD)  Female      0-14      0
# 1       Bankruptcy or Sudden change in Economic  Female      0-14      0
# 2       Cancellation/Non-Settlement of Marriage  Female      0-14      0
# 3             Physical Abuse (Rape/Incest Etc.)  Female      0-14      0
# 4                                 Dowry Dispute  Female      0-14      0
# ...

# %%
# Northern States - Total No of cases State wise
northern_df = df[df['Region'] == 'Northern'].copy()
# northern_df


state_totals = northern_df.groupby('State')['Total'].sum()


plt.figure(figsize=(8, 8))
plt.pie(state_totals, labels=state_totals.index, autopct='%1.1f%%', startangle=140, 
        colors= ["#FFEBEE", "#FFCDD2", "#EF9A9A", "#E57373", "#EF5350", "#E53935", "#D32F2F", "#C62828"])
plt.title('Distribution of Total Suicides in States of Northern Region')
plt.axis('equal')  # ensures that pie is drawn as a circle.
plt.show()

# %%
# Northern States - Total No of cases as per gender
northern_df = df[df['Region'] == 'Northern'].copy()
# northern_df


plt.figure(figsize=(12, 7))
sns.barplot(data=northern_df, x='State', y='Total', hue='Gender', palette=['pink', 'skyblue'], edgecolor='black')
plt.xlabel('States')
plt.ylabel('Total Suicides')
plt.title('Total Suicides by Gender in Northern States')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
# Southern States - Total No of cases as per gender
southern_df = df[df['Region'] == 'Southern'].copy()
# southern_df


plt.figure(figsize=(12, 7))
sns.barplot(data=southern_df, x='State', y='Total', hue='Gender', palette=['pink', 'skyblue'], edgecolor='black')
plt.xlabel('States')
plt.ylabel('Total Suicides')
plt.title('Total Suicides by Gender in Southern States')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
# Western States - Total No of cases as per gender
western_df = df[df['Region'] == 'Western'].copy()
# western_df


plt.figure(figsize=(12, 7))
sns.barplot(data=western_df, x='State', y='Total', hue='Gender', palette=['pink', 'skyblue'], edgecolor='black')
plt.xlabel('States')
plt.ylabel('Total Suicides')
plt.title('Total Suicides by Gender in Western States')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
# Eastern States - Total No of cases as per gender
eastern_df = df[df['Region'] == 'Eastern'].copy()
# eastern_df


plt.figure(figsize=(12, 7))
sns.barplot(data=eastern_df, x='State', y='Total', hue='Gender', palette=['pink', 'skyblue'], edgecolor='black')
plt.xlabel('States')
plt.ylabel('Total Suicides')
plt.title('Total Suicides by Gender in Eastern States')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
# Central States - Total No of cases as per gender
central_df = df[df['Region'] == 'Central'].copy()
# central_df


plt.figure(figsize=(12, 7))
sns.barplot(data=central_df, x='State', y='Total', hue='Gender', palette=['pink', 'skyblue'], edgecolor='black')
plt.xlabel('States')
plt.ylabel('Total Suicides')
plt.title('Total Suicides by Gender in Central States')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
# North Eastern States - Total No of cases as per gender
northeastern_df = df[df['Region'] == 'North Eastern'].copy()
# northeastern_df


plt.figure(figsize=(12, 7))
sns.barplot(data=northeastern_df, x='State', y='Total', hue='Gender', palette=['pink', 'skyblue'], edgecolor='black')
plt.xlabel('States')
plt.ylabel('Total Suicides')
plt.title('Total Suicides by Gender in North Eastern States')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
df['Type'].unique()
# Out:
# array(['Illness (Aids/STD)', 'Bankruptcy or Sudden change in Economic',
#        'Cancellation/Non-Settlement of Marriage',
#        'Physical Abuse (Rape/Incest Etc.)', 'Dowry Dispute',
#        'Family Problems', 'Ideological Causes/Hero Worshipping',
#        'Other Prolonged Illness', 'Property Dispute',
#        'Fall in Social Reputation', 'Illegitimate Pregnancy',
#        'Failure in Examination', 'Insanity/Mental Illness',
#        'Love Affairs', 'Professional/Career Problem', 'Divorce',
#        'Drug Abuse/Addiction', 'Not having Children(Barrenness/Impotency',
#        'Causes Not known', 'Unemployment',
#        'Other Causes (Please Specity)', 'Poverty', 'Death of Dear Person',
#        'Cancer', 'Suspected/Illicit Relation', 'Paralysis', 'Diploma',
#        'No Education', 'Post Graduate and Above', 'Middle', 'Graduate',
#        'Hr. Secondary/Intermediate/Pre-Universit', 'Primary',
#        'Matriculate/Secondary', 'By Consuming Insecticides', 'By Hanging',
# ...

# %%
edu_df = df[df['Type'].isin(['Diploma', 'Graduate', 'Hr. Secondary/Intermediate/Pre-Universit', 'Middle', 'No Education', 'Primary'])]
# edu_df

education = edu_df['Type'].unique()
males = []
females = []

for e in education:
    males.append(edu_df[(edu_df['Type'] == e) & (edu_df['Gender'] == 'Male')]['Total'].sum())
    females.append(edu_df[(edu_df['Type'] == e) & (edu_df['Gender'] == 'Female')]['Total'].sum())


plt.figure(figsize=(10, 6))
plt.bar(education, males, label='Male', color='red', edgecolor='black')
plt.bar(education, females, bottom=males, label='Female', color='orange', edgecolor='black')
plt.title('Total no of cases based on Education by Gender')
plt.xlabel('Education')
plt.ylabel('Total')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
eco_df = df[df['Type'].isin(['Poverty', 'Unemployment', 'Bankruptcy or Sudden change in Economic'])]
# eco_df

economic = eco_df['Type'].unique()
males = []
females = []

for e in economic:
    males.append(eco_df[(eco_df['Type'] == e) & (eco_df['Gender'] == 'Male')]['Total'].sum())
    females.append(eco_df[(eco_df['Type'] == e) & (eco_df['Gender'] == 'Female')]['Total'].sum())


plt.figure(figsize=(10, 6))
plt.bar(economic, males, label='Male', color='red', edgecolor='black')
plt.bar(economic, females, bottom=males, label='Female', color='orange', edgecolor='black')
plt.title('Total no of cases based on Economic and Employment Issues by Gender')
plt.xlabel('Economic & Employment Issues')
plt.ylabel('Total')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.show()

# %%
marital_df = df[df['Type'].isin(['Married', 'Never Married', 'Divorcee', 'Widowed/Widower'])]
# marital_df

status = marital_df['Type'].unique()
males = []
females = []

for s in status:
    males.append(marital_df[(marital_df['Type'] == s) & (marital_df['Gender'] == 'Male')]['Total'].sum())
    females.append(marital_df[(marital_df['Type'] == s) & (marital_df['Gender'] == 'Female')]['Total'].sum())


plt.figure(figsize=(10, 6))
plt.bar(status, males, label='Male', color='red', edgecolor='black')
plt.bar(status, females, bottom=males, label='Female', color='orange', edgecolor='black')
plt.title('Total no of cases based on Marital Status by Gender')
plt.xlabel('Marital Status')
plt.ylabel('Total')
plt.legend(title='Gender')
plt.show()

# %%
# Correlation between different numerical columns
df.corr(numeric_only=True)
# Out:
#            Year     Total
# Year   1.000000  0.005231
# Total  0.005231  1.000000

# %%
# Heatmap
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='viridis')
# Out:
# <Axes: >

# %%
# Pairwise relationships between variables
sns.pairplot(df)
